# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"/content/8. Netflix Dataset.csv")

# %% [markdown]
# here are the basic commands to get the information about the Dataframe

# %%
data.head() #it will show the top 5 records of the dataframe
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# Getting some information about the Dataframe

# %%
data.tail() #it shows the bottom top 5 records of the Dataframe
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.shape #it will show the shape of the Dataframe
# Out:
# (7789, 11)

# %%
data.size #it will show totaal number of elements inside the DataFrame
# Out:
# 85679

# %%
data.columns #it will show the columns names
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes #it will show the datatyple of the columns
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# Task1.Is there any duplicate record inside the dataset?if yes then remove the duplicate record

# %%
data[data.duplicated()] #it will show the duplicate records inside the dataframe
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates() #this function is used to remove any duplicate values indside the dataframe
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (7787, 11)

# %%
data[data.duplicated()] #we will check wether the dataframe is having any duplicate values or not
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# Task2.Is there any null values present in any column?show with heatmap
#
#
#
# isnull() function is used to remove the duplicate values

# %%
data.isnull() #this function is used to see the null values present inside the Dataframe
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum() #this function will show how many null values are present inside ech column
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns #it will show that how many null values are present inside the dataset

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
new=data['Title'].isin(['Zubaan']) #we are checking wether the given element is present inside the dataframe

# %%
data[new] #it is showing the specific Category
# Out:
#      Show_Id Category   Title     Director  \
# 7785   s7784    Movie  Zubaan  Mozez Singh
#
#                                                    Cast Country  \
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#        Release_Date Rating Duration  \
# 7785  March 2, 2019  TV-14  111 min
#
#                                                 Type  \
# 7785  Dramas, International Movies, Music & Musicals
#
#                                             Description
# 7785  A scrappy but poor boy worms his way into a ty...

# %%
data[data['Title'].str.contains('Zubaan')]
# Out:
#      Show_Id Category   Title     Director  \
# 7785   s7784    Movie  Zubaan  Mozez Singh
#
#                                                    Cast Country  \
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#        Release_Date Rating Duration  \
# 7785  March 2, 2019  TV-14  111 min
#
#                                                 Type  \
# 7785  Dramas, International Movies, Music & Musicals
#
#                                             Description
# 7785  A scrappy but poor boy worms his way into a ty...

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data['new_date']=pd.to_datetime(data['Release_Date'])

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data['new_date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data['new_date'].dt.day.value_counts()
# Out:
# 1.0     2069
# 15.0     644
# 31.0     274
# 2.0      247
# 16.0     240
# 20.0     219
# 10.0     213
# 5.0      207
# 19.0     203
# 8.0      190
# 22.0     185
# 30.0     182
# 25.0     180
# 18.0     178
# 26.0     174
# 28.0     172
# 21.0     172
# 6.0      165
# 7.0      162
# 14.0     161
# 12.0     156
# 27.0     153
# 13.0     153
# 17.0     153
# 4.0      151
# 23.0     138
# 24.0     136
# 29.0     130
# 3.0      127
# 11.0     123
# 9.0      120
# Name: new_date, dtype: int64

# %%
new=data['Category'].isin(['Movie','TV Show']).value_counts

# %%
data[new]
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.groupby('Category').Category.count().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
data['year']=data['new_date'].dt.year

# %%
data[data['year'].isin([2020])]
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 24       s25  TV Show      ​SAINT SEIYA: Knights of the Zodiac
# ...      ...      ...                                      ...
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#              Director                                               Cast  \
# 0                 NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data[(data['Category']=='Movie') & (data['year']==2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
data[(data['Category']=='TV Show') & (data['year']==2021)]
# Out:
#      Show_Id Category                                        Title  \
# 980     s981  TV Show                                 Bling Empire
# 1222   s1223  TV Show                              Carmen Sandiego
# 1440   s1441  TV Show                                    Cobra Kai
# 1780   s1781  TV Show                               Disenchantment
# 1864   s1865  TV Show                          Dream Home Makeover
# 2327   s2328  TV Show                            Gabby's Dollhouse
# 2672   s2673  TV Show                Headspace Guide to Meditation
# 2699   s2700  TV Show                                 Henry Danger
# 2753   s2754  TV Show                       History of Swear Words
# 3018   s3019  TV Show          Inside the World’s Toughest Prisons
# 3147   s3148  TV Show             Jenni Rivera: Mariposa de Barrio
# 3441   s3442  TV Show                   Korean Pork Belly Rhapsody
# 3472   s3473  TV Show                          Kuroko's Basketball
# ...

# %%
data[(data['Category']=='TV Show') & (data['Country'])]['Title']
# Out:
# 0                                        3%
# 5                                        46
# 11                                     1983
# 12                                     1994
# 24      ​SAINT SEIYA: Knights of the Zodiac
#                        ...
# 7768                           Zig & Sharko
# 7769                     Zindagi Gulzar Hai
# 7777                             Zoids Wild
# 7781                              Zona Rosa
# 7787                  Zumbo's Just Desserts
# Name: Title, Length: 2133, dtype: object

# %% [markdown]
# Filtering(and or operations)

# %%
data[(data['Country']=='india') & (data['Category']=='Tv Show')|(data['Category']=='Movie')] #filter function using and or
# Out:
#      Show_Id Category                                    Title  \
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# ...      ...      ...                                      ...
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
data[data['Cast']=='Elias Gergi']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, new_date, year]
# Index: []

# %%
new[new['Cast'].str.contains('Elias Gergi')]
# Out:
#      Show_Id Category Title     Director  \
# 7784   s7783    Movie  Zozo  Josef Fares
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
#
#                                                 Country      Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...  October 19, 2020
#
#      Rating Duration                          Type  \
# 7784  TV-MA   99 min  Dramas, International Movies
#
#                                             Description   new_date    year
# 7784  When Lebanon's Civil War deprives Zozo of his ... 2020-10-19  2020.0

# %%
new=data[data['Cast'].isnull()]

# %%
new=data.dropna()

# %%
new
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
hai=new['Rating'].nunique

# %%
new['Rating'].unique
# Out:
# <bound method Series.unique of 1       TV-MA
# 2           R
# 3       PG-13
# 4       PG-13
# 5       TV-MA
#         ...
# 7780        R
# 7782    TV-MA
# 7783       PG
# 7784    TV-MA
# 7785    TV-14
# Name: Rating, Length: 4809, dtype: object>
